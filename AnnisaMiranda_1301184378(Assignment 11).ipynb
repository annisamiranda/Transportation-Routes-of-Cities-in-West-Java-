# %% [markdown]
# Annisa Miranda - 1301184378

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
JB = nx.Graph()
JB.add_nodes_from(['BEKASI', 'KARAWANG', 'DEPOK', 'CIBINONG', 'BOGOR', 'CIANJUR', 'SUKABUMI', 'SOREANG', 'CIMAHI', 'BANDUNG', 'PURWAKARTA', 
                   'SUBANG', 'SUMEDANG', 'GARUT', 'TASIKMALAYA', 'CIAMIS', 'KUNINGAN', 'CIREBON', 'MAJALENGKA', 'INDRAMAYU'])
JB.nodes()
nx.draw(JB, with_labels=True)
plt.show()

# %%
JB.add_edge('KARAWANG', 'BEKASI')
JB.edges()
nx.draw(JB, with_labels=True)
plt.show()

# %%
JB.add_edge('KARAWANG', 'PURWAKARTA')
JB.edges()
nx.draw(JB, with_labels=True)
plt.show()

# %%
JB.add_edge('CIBINONG', 'DEPOK')
JB.edges()
nx.draw(JB, with_labels=True)
plt.show()

# %%
JB.add_edge('CIBINONG', 'BOGOR')
JB.edges()
nx.draw(JB, with_labels=True)
plt.show()

# %%
JB.add_edge('BOGOR', 'SUKABUMI')
JB.edges()
nx.draw(JB, with_labels=True)
plt.show()

# %%
JB.add_edge('SUKABUMI', 'CIANJUR')
JB.edges()
nx.draw(JB, with_labels=True)
plt.show()

# %%
JB.add_edge('CIANJUR', 'CIMAHI')
JB.edges()
nx.draw(JB, with_labels=True)
plt.show()

# %%
JB.add_edge('CIMAHI', 'BANDUNG')
JB.edges()
nx.draw(JB, with_labels=True)
plt.show()

# %%
JB.add_edge('SOREANG', 'BANDUNG')
JB.edges()
nx.draw(JB, with_labels=True)
plt.show()

# %%
JB.add_edge('GARUT', 'BANDUNG')
JB.edges()
nx.draw(JB, with_labels=True)
plt.show()

# %%
JB.add_edge('CIAMIS', 'TASIKMALAYA')
JB.edges()
nx.draw(JB, with_labels=True)
plt.show()

# %%
JB.add_edge('TASIKMALAYA', 'BANDUNG')
JB.edges()
nx.draw(JB, with_labels=True)
plt.show()

# %%
JB.add_edge('SUBANG', 'BANDUNG')
JB.edges()
nx.draw(JB, with_labels=True)
plt.show()

# %%
JB.add_edge('MAJALENGKA', 'SUMEDANG')
JB.edges()
nx.draw(JB, with_labels=True)
plt.show()

# %%
JB.add_edge('SUMEDANG', 'BANDUNG')
JB.edges()
nx.draw(JB, with_labels=True)
plt.show()

# %%
JB.add_edge('INDRAMAYU', 'CIREBON')
JB.edges()
nx.draw(JB, with_labels=True)
plt.show()

# %%
JB.add_edge('CIREBON', 'KUNINGAN')
JB.edges()
nx.draw(JB, with_labels=True)
plt.show()

# %%
JB.add_edge('KUNINGAN', 'MAJALENGKA')
JB.edges()
nx.draw(JB, with_labels=True)
plt.show()

# %%
JB.add_edge('KUNINGAN', 'BANDUNG')
JB.edges()
nx.draw(JB, with_labels=True)
plt.show()

# %%
JB.add_edge('PURWAKARTA', 'CIMAHI')
JB.edges()
nx.draw(JB, with_labels=True)
plt.show()

# %% [markdown]
# NETWORK VISUALIZATION

# %%
plt.figure(figsize=(20, 15))
G = nx.spring_layout(JB, k=.1)
nx.draw_networkx(JB, G, node_size=25, node_color='yellow', with_labels=True, edge_color='blue')
plt.show()

# %% [markdown]
# DEGREE CENTRALITY

# %%
nx.degree_centrality(JB)
# Out:
# {'BANDUNG': 0.3684210526315789,
#  'BEKASI': 0.05263157894736842,
#  'BOGOR': 0.10526315789473684,
#  'CIAMIS': 0.05263157894736842,
#  'CIANJUR': 0.10526315789473684,
#  'CIBINONG': 0.10526315789473684,
#  'CIMAHI': 0.15789473684210525,
#  'CIREBON': 0.10526315789473684,
#  'DEPOK': 0.05263157894736842,
#  'GARUT': 0.05263157894736842,
#  'INDRAMAYU': 0.05263157894736842,
#  'KARAWANG': 0.10526315789473684,
#  'KUNINGAN': 0.15789473684210525,
#  'MAJALENGKA': 0.10526315789473684,
#  'PURWAKARTA': 0.10526315789473684,
#  'SOREANG': 0.05263157894736842,
#  'SUBANG': 0.05263157894736842,
#  'SUKABUMI': 0.10526315789473684,
#  'SUMEDANG': 0.10526315789473684,
#  'TASIKMALAYA': 0.10526315789473684}

# %% [markdown]
# BETWEENESS CENTRALITY

# %%
nx.betweenness_centrality(JB)
# Out:
# {'BANDUNG': 0.7339181286549707,
#  'BEKASI': 0.0,
#  'BOGOR': 0.19883040935672514,
#  'CIAMIS': 0.0,
#  'CIANJUR': 0.3508771929824561,
#  'CIBINONG': 0.10526315789473684,
#  'CIMAHI': 0.6023391812865497,
#  'CIREBON': 0.10526315789473684,
#  'DEPOK': 0.0,
#  'GARUT': 0.0,
#  'INDRAMAYU': 0.0,
#  'KARAWANG': 0.10526315789473684,
#  'KUNINGAN': 0.24269005847953215,
#  'MAJALENGKA': 0.008771929824561403,
#  'PURWAKARTA': 0.19883040935672514,
#  'SOREANG': 0.0,
#  'SUBANG': 0.0,
#  'SUKABUMI': 0.2807017543859649,
#  'SUMEDANG': 0.043859649122807015,
#  'TASIKMALAYA': 0.10526315789473684}
